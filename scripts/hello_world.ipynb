# %% [markdown]
# # heading
# ## sub heading
# ### sub-sub heading
# #### sub-sub-sub heading
#
# bulleted list:
#
# - michael
# - tito
#
# numbered list:
# 1. first
# 1. second
# 1. third
# 1. fourth
#
# this is a code block: 'python3 hello_world.py'

# %%
print ('hello world')
print(7+7)
# Out:
# hello world
# 14
